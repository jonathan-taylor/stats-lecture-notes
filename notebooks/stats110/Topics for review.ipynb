# %% [markdown]
# # Part I: probability
#
# ## Chapter 2
#
# * Basic definitions
# * Counting
# * Conditional probability & independence
#
# ## Chapter 3
#
# * Discrete random variables
#      - Binomial
#      - Poisson
#
# * Probability mass function
#
# * Expected value
#
# ## Chapter 4
#
# * Continuous random variables
#     - Uniform
#     - Normal
#     - Exponential & Gamma
#
# * Probability density function
#
# * Expected value
#
# ## Chapter 5
#
# * Random vectors
#
# * Joint probablity density and mass functions
#
# * Conditional distributions
#
# * Simple random sample: IID sample from a distribution
#
# * Expected values, covariance
#
# * Distribution of the sample mean: Central Limit Theorem (CLT)

# %% [markdown]
# # Part II: Statistics
#
# ## Chapter 6
#
# * Point estimators
#
# * Method of moments
#
# * Maximum likelihood estimators
#
# ## Chapter 7
#
# * Confidence intervals
#
# * Confidence intervals for population mean (one-sample problem)
#     - Large sample (using CLT)
#     - Sample from a normal distribution (variance known)
#     - Sample from a normal distribution (variance unknown): T statistic
#
# ## Chapter 8
#
# * Hypothesis tests
#
# * Tests about a population mean (one sample problem)
#
# * Tests for a proportion
#
# ## Chapter 9
#
# * Two sample problem
#
# * Hypothesis tests and confidence intervals for the difference between two
# population means
#
# * Two sample $t$ tests
#      - Variances assumed equal (pooled)
#      - Variances assumed unequal
#      - Paired test
