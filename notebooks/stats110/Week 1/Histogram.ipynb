# %% [markdown]
# Let's make a histogram using [R](http://cran.r-project.org/). The software is installed on `corn.stanford.edu` and other Stanford servers if you don't want to install it on your own computer.
#
# ## Using provided count data
#
# We are given the following data from 1.2.23 in the textbook on the length of tantrums:
#
# Duration  | Count
# ----------|-------
# [0,2)     |  136
# [2,4)     |  92
# [4,11)    |  71
# [11,20)   |  26
# [20,30)   |  7
# [30,40)   |  3

# %%
# %%R
# counts = c(136,92,71,26,7,3)
# widths = c(2,2,7,9,10,10)
# heights = (counts / widths) / sum(counts) * 100
# barplot(heights, width=widths, xlim=c(0,40), space=0, ylab='% per unit', xlab='Units')

# %% [markdown]
# ## Using a sample of numbers
#
# More commonly, we have a sample of numbers for which we want to form
# a histogram. This means specifying the bins, then forming the above table.
#
# Most software packages have some defaults for choosing the number of bins to make
# a reasonable histogram.
#
# We will take a random sample of numbers and form a histogram.

# %%
# %%R
# random_sample = rnorm(100)
# print(random_sample)
# hist(random_sample)
# Out:
#   [1] -1.147638611 -1.251612267 -0.725433135  0.788110686 -0.903995525
#   [6] -1.790536869 -1.481621162 -0.309282274 -0.443517830 -2.312966661
#  [11] -0.612319478 -1.280611692  0.605596237  1.635882233 -0.623872669
#  [16] -0.647757995  0.817346016 -0.853045783 -1.793297654 -1.077013121
#  [21] -0.768357667 -0.471343837 -1.577953606  0.679892011  1.174805012
#  [26]  0.505447805 -0.693486295  0.032530714  0.383281765  0.501420561
#  [31]  1.740164416 -1.546733869  0.640754031 -0.123713565  1.667273860
#  [36]  2.704442530  0.351380272 -0.058532021 -0.917332622 -0.177175605
#  [41] -0.089392769 -0.095177508  0.827005224 -2.159467437 -1.923065756
#  [46]  2.094992561 -0.353149866 -0.989662731  0.002821066 -0.306881675
#  [51] -0.859138120 -1.645320704  1.262666722  0.146618544  1.168804259
#  [56]  0.688415408 -1.546922688 -1.800284326 -0.284747515 -1.354962210
#  [61] -1.093062982  1.247799622 -0.184874023 -0.503571770  1.276555529
#  [66]  0.625436934  0.882042882  0.814801650  0.788803221  0.262007614
#  [71] -0.400990238  1.465307325  1.110329054 -1.038644163  1.071777980
#  [76]  0.131242267 -0.349171128 -0.141423088 -1.083194741  0.002662093
#  [81]  1.389120642  1.819593019 -1.024131737 -1.620861338 -0.556309609
#  [86] -0.375531984 -0.244122915  0.267456162 -1.333943833  2.083701784
#  [91] -0.642331228  1.918702355  1.267505670 -0.047509743  1.455323956
#  [96]  0.813443325 -0.927518348 -0.259635654  0.856419601 -1.432041835
