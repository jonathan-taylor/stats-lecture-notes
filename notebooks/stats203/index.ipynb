# %% [markdown]
# ## Syllabus
#
# ### Instructor & TAs
#
#
# #### Instructor
#
# [Jonathan Taylor](http://www-stat.stanford.edu/~jtaylor)
#
# - Office: Sequoia Hall #137
# - Phone: 723-9230,
# - [Email](https://stanfordwho.stanford.edu/auth/lookup?search=Jonathan%20Taylor)
# - Office hours: Thursday, 12:00-2:00
#
# #### Teaching Assistants
#
# Murat Erdogdu
#
# -  [Email](https://stanfordwho.stanford.edu/auth/lookup?search=Murat%20Erdogdu)
# -  Office hours : Monday, 1:00-3:00, Sequoia Hall 220.
#
# Hera He
#
# -  [Email](https://stanfordwho.stanford.edu/auth/lookup?search=Hera%20He)
# -  Office hours : Tuesday, 2:30-4:30, Sequoia Hall 207.
#
#
# ## Email list
#
# The course has an email list that reaches all TAs as well as the professor: [stats203-win1516-staff@lists.stanford.edu](mailto:stats203-win1516-staff@lists.stanford.edu).
#
# **As a general rule, you should send course related to this email list.**
#
# ## Office hours
#
# **As a general rule, we ask students NOT to complete the assignments during TAs' in office hours. This will be easier if students do not use laptops while in TAs' office hours.**
#
# ## Schedule & Location
#
# T-Th 10:30-11:50, 380-380D
#
# ## Textbook
#
# [Statistical Models](http://www.amazon.com/Statistical-Models-Practice-David-Freedman/dp/0521743850) Freedman. *Required*
#
# [Linear Models, with R](http://www.amazon.com/Linear-Models-Chapman-Statistical-Science/dp/1439887330/ref=sr_1_1?ie=UTF8&qid=1451880121&sr=8-1&keywords=linear+models+in+R) Faraway. *Required*
#
# ## Prerequisites
#
# Some familiarity with mathematical statistics at the level of STATS 200, which is a co-requisite.
#
# ## Topics covered
#
# - Univariate regression.
# - Review of random variables, some linear algebra, law of averages (LLN and CLT).
# - Multivariate regression model. Geometry of least squares.
# - Review of random vectors, independence. Multivariate normal distribution.
# - Distribution theory for multivariate regression model under Gauss model.
# - Generalized and weighted least squares.
# - Diagnostics / outliers. Data snooping inflates $t$-statistics.
# - Model selection, some selective inference.
# - Shrinkage methods: ridge regression, LASSO.
# - Logistic / probit regression. Poisson regression.
#
# ### Comparison with STATS191
#
# This course covers many similar topics to STATS191 but in a more mathematically rigorous way. We may also cover
# additional models not covered in STATS191.
#
# ## Course organization
#
# - All relevant class information, such as homework assignments, solutions, and organizational matters, will be posted on the coursework web page.
#
# - Midterm: 2/11, in class.
#
#
# ## Evaluation
#
# * homework: 40%
# * midterm: 20%
# * final exam: 40%
#
#
# ## Homework
#
#
# - You may discuss homework problems with other students and with TAs in office hours, but you have to prepare the solutions yourself.
#
# - **As a general rule, we ask students NOT to complete the assignments during TAs' in office hours. This will be easier if students do not use laptops while in TAs' office hours.**

# %% [markdown]
# ## Computing environment
#
# - Most examples will be [jupyter notebooks](http://jupyter.org/).
#
# - Homeworks can be submitted as notebooks.
#
# - One option to get started with both `python` and `R` is [anaconda](https://www.continuum.io/downloads), along with the `r-essentials`:
#
#         conda install -c r r-essentials
#         # for using R from ipython
#         conda install -c r rpy2

# %% [markdown]
# ## Final Exam
#
# According to the [exam schedule](http://studentaffairs.stanford.edu/registrar/students/winter-exams) our exam is to be held on March 17, at 12:15 PM.
#
# ### Practice final
#
# Here is a [practice final](practice.pdf).

# %% [markdown]
# ## Notes
#
# - [Yule's pauper data](http://nbviewer.ipython.org/url/web.stanford.edu/class/stats203/notebooks/Yule pauper data.ipynb)
#
# - [Simple linear regression](http://nbviewer.ipython.org/url/web.stanford.edu/class/stats203/notebooks/Simple linear regression.ipynb)
#
# - [Matrices review](http://nbviewer.ipython.org/url/web.stanford.edu/class/stats203/notebooks/Matrices review.ipynb)
#
# - [R tips](http://nbviewer.ipython.org/url/web.stanford.edu/class/stats203/notebooks/Some tips on R.ipynb)
#
# - [Multiple linear regression](http://nbviewer.ipython.org/url/web.stanford.edu/class/stats203/notebooks/Multiple linear regression.ipynb)
#
# - [Diagnostics](http://nbviewer.ipython.org/url/web.stanford.edu/class/stats203/notebooks/Diagnostics for multiple regression.ipynb)
#
# - [Selection](http://nbviewer.ipython.org/url/web.stanford.edu/class/stats203/notebooks/Selection.ipynb)
#
# - [Data snooping](http://nbviewer.ipython.org/url/web.stanford.edu/class/stats203/notebooks/Data snooping.ipynb)
#
# - [Penalized regression](http://nbviewer.ipython.org/url/web.stanford.edu/class/stats203/notebooks/Penalized regression.ipynb)
#
# - [Logistic regression](http://nbviewer.ipython.org/url/web.stanford.edu/class/stats203/notebooks/Logistic.ipynb)
#
# - [Bootstrapping regression](http://nbviewer.ipython.org/url/web.stanford.edu/class/stats203/notebooks/Bootstrapping regression.ipynb)
#
# - [ANOVA](http://nbviewer.ipython.org/url/web.stanford.edu/class/stats203/notebooks/ANOVA.ipynb)
#
# - [Review](http://nbviewer.ipython.org/url/web.stanford.edu/class/stats203/notebooks/Review.ipynb)
#
# ## Assignments
#
# - [Assignment 1](http://nbviewer.ipython.org/url/web.stanford.edu/class/stats203/notebooks/Assignment1.ipynb)
#
# - [Assignment 2](http://nbviewer.ipython.org/url/web.stanford.edu/class/stats203/notebooks/Assignment2.ipynb)
#
# - [Assignment 3](http://nbviewer.ipython.org/url/web.stanford.edu/class/stats203/notebooks/Assignment3.ipynb)
#
# - [Assignment 4](http://nbviewer.ipython.org/url/web.stanford.edu/class/stats203/notebooks/Assignment4.ipynb)
